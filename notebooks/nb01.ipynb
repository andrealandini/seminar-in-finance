# %%
https://polymarket.com/event/will-the-next-pope-be-a-dark-horse-candidate


https://polymarket.com/event/who-will-be-the-next-pope

# %%
curl -s "https://clob.polymarket.com/prices-history?market=113845724700054083561790691604568760899627369924969834963221702983533500982036&interval=max&fidelity=60" | head -c 2000

# %%
curl -s "https://clob.polymarket.com/prices-history?market=113845724700054083561790691604568760899627369924969834963221702983533500982036&interval=max&fidelity=60" | head -c 2000
{"history":[]}
